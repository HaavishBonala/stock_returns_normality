# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import yfinance as yf
print(pd.__version__, np.__version__, yf.__version__)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 3.0.5 2.5.1 1.5.2

# %%
spx = yf.download(tickers="^GSPC",start="2005-01-01",end="2025-08-31",auto_adjust=False)
print(spx.shape)
print(spx.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# (5198, 5)
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2005-01-03  1202.079956  1217.800049  1200.319946  1211.920044  1510800000
# 2005-01-04  1188.050049  1205.839966  1185.390015  1202.079956  1721000000
# 2005-01-05  1183.739990  1192.729980  1183.719971  1188.050049  1738900000
# 2005-01-06  1187.890015  1191.630005  1183.270020  1183.739990  1569100000
# 2005-01-07  1186.189941  1192.199951  1182.160034  1187.890015  1477900000

# %%
apple = yf.download(tickers="AAPL",start="2005-01-01",end="2025-08-31",auto_adjust=False)
print(apple.shape)
print(apple)
# Out:
# [*********************100%***********************]  1 of 1 completed
# (5198, 6)
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2005-01-03    0.947307    1.130179    1.162679    1.117857    1.156786
# 2005-01-04    0.957036    1.141786    1.169107    1.124464    1.139107
# 2005-01-05    0.965417    1.151786    1.165179    1.143750    1.151071
# 2005-01-06    0.966166    1.152679    1.159107    1.130893    1.154821
# 2005-01-07    1.036514    1.236607    1.243393    1.156250    1.160714
# ...                ...         ...         ...         ...         ...
# 2025-08-25  226.519165  227.160004  229.300003  226.229996  226.479996
# 2025-08-26  228.663086  229.309998  229.490005  224.690002  226.869995
# 2025-08-27  229.839767  230.490005  230.899994  228.259995  228.610001
# 2025-08-28  231.903931  232.559998  233.410004  229.339996  230.820007
# ...
